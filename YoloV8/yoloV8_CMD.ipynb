# %% [markdown]
# # Installation

# %%
# !pip install ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      -------- ------------------------------- 0.3/1.3 MB 8.6 MB/s eta 0:00:01
#      ---------------------- ----------------- 0.8/1.3 MB 9.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 12.2 MB/s eta 0:00:00
# ...
#   Using cached ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# ...
#   Using cached torchvision-0.27.1-cp310-cp310-win_amd64.whl (3.5 MB)
# ...
#   Using cached torch-2.12.1-cp310-cp310-win_amd64.whl (122.9 MB)
# ...
#   Using cached nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# ...
#   Using cached polars-1.42.1-py3-none-any.whl (837 kB)
# ...
#   Using cached polars_runtime_32-1.42.1-cp310-abi3-win_amd64.whl (52.7 MB)
# ...
#   Using cached fsspec-2026.6.0-py3-none-any.whl (203 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ...
#      ---------------------------------------- 0.0/45.1 kB ? eta -:--:--
#      ---------------------------------------- 45.1/45.1 kB 2.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # CMD

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # 1. Detection

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="images.jpg"
# Out:
# Ultralytics 8.4.86  Python-3.10.11 torch-2.12.1+cpu CPU (AMD Ryzen 5 7530U with Radeon Graphics)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 d:\Desktop\Computer Vision\YoloV8\images.jpg: 448x640 2 persons, 1 dog, 58.1ms
# Speed: 2.5ms preprocess, 58.1ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to D:\Desktop\Computer Vision\runs\detect\predict
#  Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Segmentation

# %%
# !yolo task = segment mode=predict model=yolov8n-seg.pt source = "images.jpg"
# Out:
# ...
# Ultralytics 8.4.86  Python-3.10.11 torch-2.12.1+cpu CPU (AMD Ryzen 5 7530U with Radeon Graphics)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 d:\Desktop\Computer Vision\YoloV8\images.jpg: 448x640 3 persons, 2 cats, 2 dogs, 127.5ms
# Speed: 5.2ms preprocess, 127.5ms inference, 12.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to D:\Desktop\Computer Vision\runs\segment\predict
#  Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 3. Classification

# %%
# !yolo task = classify mode = predict model = yolov8n-cls.pt source = "images.jpg"
# Out:
# ...
# Ultralytics 8.4.86  Python-3.10.11 torch-2.12.1+cpu CPU (AMD Ryzen 5 7530U with Radeon Graphics)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
#
# ...
# image 1/1 d:\Desktop\Computer Vision\YoloV8\images.jpg: 224x224 Italian_greyhound 0.36, whippet 0.12, Siberian_husky 0.11, Eskimo_dog 0.09, Chihuahua 0.08, 12.8ms
# Speed: 9.5ms preprocess, 12.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to D:\Desktop\Computer Vision\runs\classify\predict
#  Learn more at https://docs.ultralytics.com/modes/predict
